# %%
# Задание 1. Выделить все биграммы в этом тексте и сохранить их список в какую-либо переменную
text = ["варкалось хливкие шорьки пырялись по наве и хрюкотали зелюки как мюмзики в мове о бойся бармаглота сын он так свирлеп и дик а в глyще рымит исполин злопастный брандашмыг"]
for line in text:
    words = line.split()
    bigrams = []
    for i in range(len(words)-1):
        bigrams.append([words[i], words[i+1]])
print(bigrams)
# Out:
# [['варкалось', 'хливкие'], ['хливкие', 'шорьки'], ['шорьки', 'пырялись'], ['пырялись', 'по'], ['по', 'наве'], ['наве', 'и'], ['и', 'хрюкотали'], ['хрюкотали', 'зелюки'], ['зелюки', 'как'], ['как', 'мюмзики'], ['мюмзики', 'в'], ['в', 'мове'], ['мове', 'о'], ['о', 'бойся'], ['бойся', 'бармаглота'], ['бармаглота', 'сын'], ['сын', 'он'], ['он', 'так'], ['так', 'свирлеп'], ['свирлеп', 'и'], ['и', 'дик'], ['дик', 'а'], ['а', 'в'], ['в', 'глyще'], ['глyще', 'рымит'], ['рымит', 'исполин'], ['исполин', 'злопастный'], ['злопастный', 'брандашмыг']]

# %%
# Задание 2
# 2_1 Распечатать текущую директорию и список всех файлов и папок в ней
import os
os.chdir('C:\\Users\\Elena\\minor\\python-dh-hw\\poems')
os.getcwd()
for file in os.listdir('.'):
    print(file)
file_count = sum(len(files) for _, _, files in os.walk(r'.'))
print(file_count)
# Out:
# боль.txt
# ворон.txt
# деды.txt
# кладь.txt
# котики
# ночь.txt
# сказки
# шредингер.txt
# 14

# %%
# Задание 3
## 3_1 Скопировать текст, сохранить его в переменную
sentence = """Несчастная кошка порезала лапу- 
Сидит, и ни шагу не может ступить.
Скорей, чтобы вылечить кошкину лапу
Воздушные шарики надо купить!

И сразу столпился народ на дороге-
Шумит, и кричит, и на кошку глядит.
А кошка отчасти идет по дороге,
Отчасти по воздуху плавно летит!"""
print(sentence)
# Out:
# Несчастная кошка порезала лапу-
# Сидит, и ни шагу не может ступить.
# Скорей, чтобы вылечить кошкину лапу
# Воздушные шарики надо купить!
#
# И сразу столпился народ на дороге-
# Шумит, и кричит, и на кошку глядит.
# А кошка отчасти идет по дороге,
# Отчасти по воздуху плавно летит!

# %%
## 3_2 Узнать длину текста в символах
print(len(sentence))
# Out:
# 270

# %%
## 3_3 Очистить текст от пунктуации
words = [word.strip("!?.,-") for word in sentence.split()]
print(words)
# Out:
# ['Несчастная', 'кошка', 'порезала', 'лапу', 'Сидит', 'и', 'ни', 'шагу', 'не', 'может', 'ступить', 'Скорей', 'чтобы', 'вылечить', 'кошкину', 'лапу', 'Воздушные', 'шарики', 'надо', 'купить', 'И', 'сразу', 'столпился', 'народ', 'на', 'дороге', 'Шумит', 'и', 'кричит', 'и', 'на', 'кошку', 'глядит', 'А', 'кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
## 3_4 Объединить слова из получившегося списка в строку через пробел
s = ' '.join(words)
print(s)
# Out:
# Несчастная кошка порезала лапу Сидит и ни шагу не может ступить Скорей чтобы вылечить кошкину лапу Воздушные шарики надо купить И сразу столпился народ на дороге Шумит и кричит и на кошку глядит А кошка отчасти идет по дороге Отчасти по воздуху плавно летит

# %%
## 3_5 С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру
sent = s
print([w for w in sent.istitle() if sent.lower()])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e2c17ed7fd2f> in <module>()
#       1 ## 3_5 С помощью list comprehensions проверить, написано ли слово с большой буквы, и если да, то привести его к нижнему регистру
#       2 sent = s
# ----> 3 print([w for w in sent.istitle() if sent.lower()])
#       4
#       5 print(sent.lower())
#
# TypeError: 'bool' object is not iterable

# %%
print(sent.lower())
# Out:
# несчастная кошка порезала лапу сидит и ни шагу не может ступить скорей чтобы вылечить кошкину лапу воздушные шарики надо купить и сразу столпился народ на дороге шумит и кричит и на кошку глядит а кошка отчасти идет по дороге отчасти по воздуху плавно летит

# %%
## 3_6 Узнать длину текста в словах
words = sentence.split()
print(len(words))
# Out:
# 44

# %%
## 3_7 Узнать количество уникальных слов
import collections
c = collections.Counter()

# %%
## 3_8 Распечатать последние 10 слов
words = sent.split()[-10:]
print(words)
# Out:
# ['кошка', 'отчасти', 'идет', 'по', 'дороге', 'Отчасти', 'по', 'воздуху', 'плавно', 'летит']

# %%
## 3_9 Соединить полученный в пункте 3 список в строку
s = '\n'.join(sentence)
print(s)
# Out:
# Н
# е
# с
# ч
# а
# с
# т
# н
# а
# я
#
# к
# о
# ш
# к
# а
#
# п
# о
# р
# е
# з
# а
# л
# а
#
# л
# а
# п
# у
# -
#
#
#
# С
# и
# д
# и
# т
# ,
#
# и
#
# н
# и
#
# ш
# а
# г
# у
#
# н
# е
#
# м
# о
# ж
# е
# т
#
# с
# т
# у
# п
# и
# т
# ь
# .
#
#
# С
# к
# о
# р
# е
# й
# ,
#
# ч
# т
# о
# б
# ы
#
# в
# ы
# л
# е
# ч
# и
# т
# ь
#
# к
# о
# ш
# к
# и
# н
# у
#
# л
# а
# п
# у
#
#
# В
# о
# з
# д
# у
# ш
# н
# ы
# е
#
# ш
# а
# р
# и
# к
# и
#
# н
# а
# д
# о
#
# к
# у
# п
# и
# т
# ь
# !
#
#
#
#
# И
#
# с
# р
# а
# з
# у
#
# с
# т
# о
# л
# п
# и
# л
# с
# я
#
# н
# а
# р
# о
# д
#
# н
# а
#
# д
# о
# р
# о
# г
# е
# -
#
#
# Ш
# у
# м
# и
# т
# ,
#
# и
#
# к
# р
# и
# ч
# и
# т
# ,
#
# и
#
# н
# а
#
# к
# о
# ш
# к
# у
#
# г
# л
# я
# д
# и
# т
# .
#
#
# А
#
# к
# о
# ш
# к
# а
#
# о
# т
# ч
# а
# с
# т
# и
#
# и
# д
# е
# т
#
# п
# о
#
# д
# о
# р
# о
# г
# е
# ,
#
#
# О
# т
# ч
# а
# с
# т
# и
#
# п
# о
#
# в
# о
# з
# д
# у
# х
# у
#
# п
# л
# а
# в
# н
# о
#
# л
# е
# т
# и
# ...

# %%
## 3_10 Распечатать с 20 по 30 символ этой строки (включительно)
print(s[19:31])
# Out:
#
# к
# о
# ш
# к
# а

# %%
## 3_11 Разбить текст на биграммы, записать их в переменную и посчитать частотность каждой биграммы
text = [sentence]
for line in text:
    words = line.split()
    bigrams = []
    for i in range(len(words)-1):
        bigrams.append([words[i], words[i+1]])
print(bigrams)
# Out:
# [['Несчастная', 'кошка'], ['кошка', 'порезала'], ['порезала', 'лапу-'], ['лапу-', 'Сидит,'], ['Сидит,', 'и'], ['и', 'ни'], ['ни', 'шагу'], ['шагу', 'не'], ['не', 'может'], ['может', 'ступить.'], ['ступить.', 'Скорей,'], ['Скорей,', 'чтобы'], ['чтобы', 'вылечить'], ['вылечить', 'кошкину'], ['кошкину', 'лапу'], ['лапу', 'Воздушные'], ['Воздушные', 'шарики'], ['шарики', 'надо'], ['надо', 'купить!'], ['купить!', 'И'], ['И', 'сразу'], ['сразу', 'столпился'], ['столпился', 'народ'], ['народ', 'на'], ['на', 'дороге-'], ['дороге-', 'Шумит,'], ['Шумит,', 'и'], ['и', 'кричит,'], ['кричит,', 'и'], ['и', 'на'], ['на', 'кошку'], ['кошку', 'глядит.'], ['глядит.', 'А'], ['А', 'кошка'], ['кошка', 'отчасти'], ['отчасти', 'идет'], ['идет', 'по'], ['по', 'дороге,'], ['дороге,', 'Отчасти'], ['Отчасти', 'по'], ['по', 'воздуху'], ['воздуху', 'плавно'], ['плавно', 'летит!']]
